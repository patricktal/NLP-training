# %%
! git clone  https://github.com/Jakobovski/free-spoken-digit-dataset
# Out:
# Cloning into 'free-spoken-digit-dataset'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 3166 (delta 3), reused 8 (delta 3), pack-reused 3157
# Receiving objects: 100% (3166/3166), 23.92 MiB | 26.33 MiB/s, done.
# Resolving deltas: 100% (72/72), done.

# %%
! ls free-spoken-digit-dataset/recordings/7_jackson_37.wav
# Out:
# free-spoken-digit-dataset/recordings/7_jackson_37.wav

# %%
from IPython.display import display, Audio

# %%
display(Audio(filename="free-spoken-digit-dataset/recordings/7_jackson_49.wav", rate=1))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
! cd free-spoken-digit-dataset && pwd

# %%
! pwd
# Out:
# /content

# %%
import torch.nn as nn
